# %%
from pynq import Overlay
overlay = Overlay("prio.bit")

# %%
overlay.ip_dict
# Out:
# {'pr_0/axi_gpio_0': {'addr_range': 65536,
#   'device': <pynq.pl_server.device.XlnkDevice at 0xb442ea90>,
#   'driver': pynq.lib.axigpio.AxiGPIO,
#   'fullpath': 'pr_0/axi_gpio_0',
#   'gpio': {},
#   'interrupts': {'ip2intc_irpt': {'controller': 'system_interrupts',
#     'fullpath': 'pr_0/axi_gpio_0/ip2intc_irpt',
#     'index': 0}},
#   'mem_id': 'S_AXI',
#   'parameters': {'C_ALL_INPUTS': '0',
#    'C_ALL_INPUTS_2': '0',
#    'C_ALL_OUTPUTS': '0',
#    'C_ALL_OUTPUTS_2': '0',
#    'C_BASEADDR': '0x41200000',
#    'C_DOUT_DEFAULT': '0x00000000',
#    'C_DOUT_DEFAULT_2': '0x00000000',
#    'C_FAMILY': 'zynq',
#    'C_GPIO2_WIDTH': '32',
#    'C_GPIO_WIDTH': '6',
#    'C_HIGHADDR': '0x4120FFFF',
#    'C_INTERRUPT_PRESENT': '1',
#    'C_IS_DUAL': '0',
#    'C_S_AXI_ADDR_WIDTH': '9',
#    'C_S_AXI_DATA_WIDTH': '32',
#    'C_TRI_DEFAULT': '0x00000000',
#    'C_TRI_DEFAULT_2': '0xFFFFFFFF',
#    'Component_Name': 'prio_axi_gpio_0_0',
#    'EDK_IPTYPE': 'PERIPHERAL',
# ...

# %%
GPIO = overlay.pr_0

# %%
from pynq import GPIO

output = GPIO(GPIO.get_gpio_pin(0), 'out')
input = GPIO(GPIO.get_gpio_pin(1), 'in')

output.write(0)
input.read()
# Out:
# 0
